# %%
 import pandas as pd
df = pd.read_csv(r'Downloads\diabetes.csv')
df
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# ...

# %%
colname = list(df)
i=colname   
dicts={}

for x in i:
    df_new = df[x].unique()  
    #print(x ,",",len(df_new))
    y =len(df_new)
    #print (y)
    dicts[x] = y
print(dicts)
# Out:
# {'Pregnancies': 17, 'Glucose': 136, 'BloodPressure': 47, 'SkinThickness': 51, 'Insulin': 186, 'BMI': 248, 'DiabetesPedigreeFunction': 517, 'Age': 52, 'Outcome': 2}

# %%
import pandas as pd

colname = list(df)
i=colname   
dicts={}

for x in i:
    df_new = df[x].unique()  
    #print(x ,",",len(df_new))
    y =len(df_new)
    #print (y)
    dicts[x] = y
print(dicts)

df1 = pd.DataFrame(list(dicts.items()),columns=['Column_name','Unique_value'])
df1
# Out:
# {'Pregnancies': 17, 'Glucose': 136, 'BloodPressure': 47, 'SkinThickness': 51, 'Insulin': 186, 'BMI': 248, 'DiabetesPedigreeFunction': 517, 'Age': 52, 'Outcome': 2}
#                 Column_name  Unique_value
# 0               Pregnancies            17
# 1                   Glucose           136
# 2             BloodPressure            47
# 3             SkinThickness            51
# 4                   Insulin           186
# 5                       BMI           248
# 6  DiabetesPedigreeFunction           517
# 7                       Age            52
# 8                   Outcome             2

# %%
import pandas as pd
df= pd.read_csv(r'Downloads\diabetes.csv')
df_new= df.iloc[:,0:3]
df_new
# Out:
#      Pregnancies  Glucose  BloodPressure
# 0              6      148             72
# 1              1       85             66
# 2              8      183             64
# 3              1       89             66
# 4              0      137             40
# ..           ...      ...            ...
# 763           10      101             76
# 764            2      122             70
# 765            5      121             72
# 766            1      126             60
# 767            1       93             70
#
# [768 rows x 3 columns]

# %%
import pandas as pd
df=pd.read_csv(r'Downloads\diabetes.csv')
df_new=df.iloc[:,7:]
df_new
# Out:
#      Age  Outcome
# 0     50        1
# 1     31        0
# 2     32        1
# 3     21        0
# 4     33        1
# ..   ...      ...
# 763   63        0
# 764   27        0
# 765   30        0
# 766   47        1
# 767   23        0
#
# [768 rows x 2 columns]

# %%
import pandas as pd
df=pd.read_csv(r'Downloads\diabetes.csv')
df_new=df.iloc[50:151,:]
df_new
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 50             1      103             80             11       82  19.4
# 51             1      101             50             15       36  24.2
# 52             5       88             66             21       23  24.4
# 53             8      176             90             34      300  33.7
# 54             7      150             66             42      342  34.7
# ..           ...      ...            ...            ...      ...   ...
# 146            9       57             80             37        0  32.8
# 147            2      106             64             35      119  30.5
# 148            5      147             78              0        0  33.7
# 149            2       90             70             17        0  27.3
# 150            1      136             74             50      204  37.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 50                      0.491   22        0
# ...

# %%
import pandas as pd
import numpy as np
df = pd.read_csv(r'Downloads\diabetes.csv')
df['Pregnancies']= np.select(>10)
# Out:
#   Cell In[66], line 4
#     df['Pregnancies']= np.select(>10)
#                                  ^
# SyntaxError: invalid syntax

# %%
import numpy as np
df = pd.read_csv(r"Downloads\diabetes.csv")
df=df[df['Pregnancies']>10]
df
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 24            11      143             94             33      146  36.6
# 28            13      145             82             19      110  22.2
# 36            11      138             76              0        0  33.2
# 72            13      126             90              0        0  43.4
# 86            13      106             72             54        0  36.6
# 88            15      136             70             32      110  37.1
# 159           17      163             72             41      114  40.9
# 193           11      135              0              0        0  52.3
# 215           12      151             70             40      271  41.8
# 254           12       92             62              7      258  27.6
# 259           11      155             76             28      150  33.3
# 274           13      106             70              0        0  34.2
# ...

# %%
pwd
# Out:
# 'C:\\Users\\Tech'
